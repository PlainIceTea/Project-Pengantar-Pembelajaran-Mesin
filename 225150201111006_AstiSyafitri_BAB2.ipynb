# %% [markdown]
# # Praktikum Pengantar Pembelajaran Mesin
#
#
# ---
# ## Bab 2. Pemrosesan Awal Data

# %% [markdown]
# ### 1) Import Data

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Unduh dataset yang akan digunakan pada praktikum kali ini. Anda dapat menggunakan aplikasi **wget** untuk mendowload dataset dan menyimpannya dalam Google Colab. Jalankan cell di bawah ini untuk mengunduh dataset

# %%
! wget https://dataset-ppm.s3.amazonaws.com/iris_missing.csv
# Out:
# --2024-03-04 03:35:33--  https://dataset-ppm.s3.amazonaws.com/iris_missing.csv
# Resolving dataset-ppm.s3.amazonaws.com (dataset-ppm.s3.amazonaws.com)... 52.219.106.172, 52.219.93.148, 52.219.103.84, ...
# Connecting to dataset-ppm.s3.amazonaws.com (dataset-ppm.s3.amazonaws.com)|52.219.106.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4593 (4.5K) [text/csv]
# Saving to: ‘iris_missing.csv’
#
# iris_missing.csv    100%[===================>]   4.49K  --.-KB/s    in 0s
#
# 2024-03-04 03:35:33 (158 MB/s) - ‘iris_missing.csv’ saved [4593/4593]

# %% [markdown]
# Setelah dataset berhasil diunduh, langkah berikutnya adalah membaca dataset dengan memanfaatkan fungsi [readcsv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) dari library pandas. Lakukan pembacaan berkas csv menggunakan fungsi **readcsv**. Jangan lupa untuk melakukan import library pandas terlebih dahulu

# %%
df = pd.read_csv('iris_missing.csv')

# %% [markdown]
# Tampilkan beberapa baris dari dataset untuk mendapatkan informasi singkat mengenai isi data. Gunakan fungsi **head()** untuk menampilkan 5 data pertama.

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           0.0          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Berdasarkan informasi dari fungsi **head()**, data iris yang
# digunakan mempunyai 4 fitur sebagai berikut :
#
#
# 1.   sepal length
# 2.   sepal width
# 3.   petal length
# 4.   petal width

# %% [markdown]
# ### 2) Missing value dan imputasi data
#
#
#
#
# Jika Anda perhatikan dengan seksama, data pada baris ke-3 (index 2) pada fitur sepal length memiliki nilai 0.0. Hal ini menandakan adanya missing value pada data. Jalankan cell di bawah ini untuk mendapatkan semua data yang mengandung missing value. Pencarian data yang mengandung missing value dilakukan dengan tahapan sebagai berikut:
#
#
# 1.   Membuat filter untuk mencari data dengan sepal_length = 0, sepal_width = 0, petal_length = 0, petal_width =0
# 2.   Mencari data yang memenuhi kondisi1 **atau** kondisi2 **atau** kondisi3 **atau** kondisi4 menggunakan property [loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) pada dataframe

# %%
sLength_missing = df['sepal_length'] == 0
sWidth_missing = df['sepal_width'] == 0
pLength_missing = df['petal_length'] == 0
pWidth_missing = df['petal_width'] == 0
df.loc[sLength_missing]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         Species
# 2             0.0          3.2           1.3          0.2     Iris-setosa
# 11            0.0          3.4           1.6          0.2     Iris-setosa
# 107           0.0          2.9           6.3          1.8  Iris-virginica

# %%
df.loc[df['sepal_length'] == 4.9]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          Species
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 34            4.9          3.1           1.5          0.2      Iris-setosa
# 37            4.9          3.6           1.4          0.1      Iris-setosa
# 57            4.9          2.4           3.3          1.0  Iris-versicolor
# 106           4.9          2.5           4.5          1.7   Iris-virginica

# %%
df['sepal_length'] == 0
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: sepal_length, Length: 150, dtype: bool

# %% [markdown]
# Penanganan missing value pada Pandas akan lebih mudah apabila data yang hilang (bernilai 0.0) diganti dengan NaN (Not A Number). Gunakan properti **replace** pada dataframe untuk menggganti 0.0 menjadi NaN

# %%
iris_new = df.replace(0.0, np.NaN)
# iris_new = iris_new.replace(np.NaN, 0.0)
iris_new.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           NaN          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Check the total of missing values
iris_new.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2            True        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False         True    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris_new.isna().sum()
# Out:
# sepal_length    3
# sepal_width     3
# petal_length    3
# petal_width     4
# Species         0
# dtype: int64

# %%
iris_new.isnull().sum()
# Out:
# sepal_length    3
# sepal_width     3
# petal_length    3
# petal_width     4
# Species         0
# dtype: int64

# %% [markdown]
# Terdapat beberapa cara untuk mengatasi permasalahan missing value pada data. Salah satu cara yang sederhana adalah dengan mengganti nilai NaN pada suatu fitur dengan rata-rata nilai fitur tersebut pada data lain yang bernilai bukan Nan. Perhatikan bahwa Anda harus mengganti nilai NaN dengan rata-rata data lain yang memiliki kategori (species) yang sama.
#
# Fungsi-fungsi pada Pandas yang dapat Anda manfaatkan:
#
#
# 1.   **transform** untuk mengaplikasikan fungsi tertentu pada dataframe, pada permasalahan ini fungsi yang digunakan adalah fungsi **mean**
# 2.   **groupby** untuk mengelompokkan dataframe berdasarkan nilai kolom tertentu, pada permasalahan ini kolom yang digunakan adalah **species**
# 3. **fillna** untuk mengganti nilai NaN dengan nilai yang telah ditentukan
#
#
#
#
# Buatlah fungsi bernama **imputasi** yang melakukan tahapan berikut:
#
#
# 1.   Menghitung rata-rata masing-masing kolom berdasarkan kelasnya
# 2.   Mengisi kolom yang berisi NaN dengan rata-rata kelas yang sesuai

# %%
def imputasi(df_input):
  list_columns = df_input.columns[:-1] #mengambil column kecuali yang terakhir
  class_column = df_input.columns[-1] #mengambil data label saja
  for column in list_columns:
    df_input[column] = df_input[column].fillna(df_input.groupby(class_column)[column].transform('mean'))
  return df_input

# %%
iris_new.columns[:-1]
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %%
class_columns = iris_new.columns[-1]
print(class_columns)
# Out:
# Species

# %% [markdown]
# Buatlah sebuah dataframe baru bernama **data_imputasi** yang berisi dataset dengan nilai NaN yang sudah diganti dengan cara memanggil fungsi **imputasi**.

# %%
data_imputasi = imputasi(iris_new)
data_imputasi.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0      5.100000          3.5           1.4          0.2  Iris-setosa
# 1      4.900000          3.0           1.4          0.2  Iris-setosa
# 2      5.016667          3.2           1.3          0.2  Iris-setosa
# 3      4.600000          3.1           1.5          0.2  Iris-setosa
# 4      5.000000          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Cek apakah masih terdapat nilai NaN pada dataframe.

# %%
data_imputasi.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64

# %% [markdown]
# ### 3) Normalisasi MinMax
# Normalisasi bertujuan menyamakan rentang nilai pada setiap fitur. Beberapa metode pembelajaran mesin memiliki kinerja yang buruk apabila rentang nilai tiap variabel berbeda jauh.
#
# Sebelum melakukan normalisasi, cek terlebih dahulu rentang (nilai max - nilai min) pada masing masing fitur

# %%
def cetak_rentang(df_input):
  list_fitur = df_input.columns[:-1]
  for fitur in list_fitur:
    max = df_input[fitur].max()
    min = df_input[fitur].min()
    print("Rentang fitur", fitur, " adalah ", max-min)

# %%
cetak_rentang(data_imputasi)
# Out:
# Rentang fitur sepal_length  adalah  3.6000000000000005
# Rentang fitur sepal_width  adalah  2.4000000000000004
# Rentang fitur petal_length  adalah  5.9
# Rentang fitur petal_width  adalah  2.4

# %% [markdown]
# Terlihat bahwa masing-masing fitur memiliki rentang yang berbeda, meskipun tidak terlalu signifikan. Pada praktikum ini Anda akan mengimplementasikan normalisasi MinMax untuk menyamakan rentang setiap fitur menjadi satu (1). Persamaan dari fungsi normalisasi MinMax adalah sebagai berikut:
#
# $x'=\frac{x-min(x)}{max(x)-min(x)}$
#
# dimana $x'$ merupakan nilai ternormalisasi, $x$ adalah nilai asal, $min(x)$ merupakan nilai minimum pada suatu fitur, dan $max(x)$ merupakan nilai maksimum pada suatu fitur.
#
# Implementasikan metode normalisasi MinMax pada fungsi bernama **minmax**.

# %%
def minmax(df_input):
  df_minmax = df_input.copy()
  list_fitur = df_minmax.columns[:-1]
  for fitur in list_fitur:
    max = df_minmax[fitur].max()
    min = df_minmax[fitur].min()
    df_minmax[fitur] = (df_minmax[fitur]-min) / (max - min)
  return df_minmax

# %% [markdown]
# Buatlah sebuah dataframe baru bernama **data_normal** yang berisi hasil dari metode minmax dengan input **data_imputasi**

# %%
data_normal = minmax(data_imputasi)

# %% [markdown]
# Cek 5 baris pertama **data_normal**

# %%
data_normal.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0      0.222222     0.625000      0.067797     0.041667  Iris-setosa
# 1      0.166667     0.416667      0.067797     0.041667  Iris-setosa
# 2      0.199074     0.500000      0.050847     0.041667  Iris-setosa
# 3      0.083333     0.458333      0.084746     0.041667  Iris-setosa
# 4      0.194444     0.666667      0.067797     0.041667  Iris-setosa

# %%
data_imputasi.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0      5.100000          3.5           1.4          0.2  Iris-setosa
# 1      4.900000          3.0           1.4          0.2  Iris-setosa
# 2      5.016667          3.2           1.3          0.2  Iris-setosa
# 3      4.600000          3.1           1.5          0.2  Iris-setosa
# 4      5.000000          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# Tampilkan rentang masing-masing fitur menggunakan fungsi **cetak_rentang** yang telah dibuat

# %%
cetak_rentang(data_normal)
# Out:
# Rentang fitur sepal_length  adalah  1.0
# Rentang fitur sepal_width  adalah  1.0
# Rentang fitur petal_length  adalah  1.0
# Rentang fitur petal_width  adalah  1.0

# %% [markdown]
# ## TUGAS
# 1. Implementasikan metode normalisasi Z-score dengan cara membuat fungsi bernama **zscore**.
# 2. Normalisasikan dataframe **data_imputasi** menggunakan fungsi **zscore**. Simpan hasilnya pada dataframe bernama **data_zscore**.
# 3. Jelaskan perbedaan hasil normalisasi **MinMax** dan **ZScore**. Petunjuk : cek nilai rentang, rata-rata dan standar deviasi dari **data_zscore**.

# %%
def zscore(df_input):
  df_zscore = df_input.copy()
  list_fitur = df_zscore.columns[:-1]
  for fitur in list_fitur:
    data = df_zscore[fitur]
    meanData = df_zscore[fitur].mean()
    df_zscore[fitur] = (df_zscore[fitur]-meanData) / df_zscore[fitur].std()
  return df_zscore

# %% [markdown]
# 2. Normalisasikan dataframe data_imputasi menggunakan fungsi zscore. Simpan hasilnya pada dataframe bernama data_zscore.

# %%
data_zscore = zscore(data_imputasi)

# %%
data_zscore.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0     -0.907825     1.053430     -1.336763    -1.312509  Iris-setosa
# 1     -1.152507    -0.110540     -1.336763    -1.312509  Iris-setosa
# 2     -1.009776     0.355048     -1.393408    -1.312509  Iris-setosa
# 3     -1.519530     0.122254     -1.280117    -1.312509  Iris-setosa
# 4     -1.030166     1.286224     -1.336763    -1.312509  Iris-setosa

# %% [markdown]
# Jelaskan perbedaan hasil normalisasi MinMax dan ZScore. Petunjuk : cek nilai rentang, rata-rata dan standar deviasi dari data_zscore.

# %% [markdown]
# 2. Hasil

# %%
data_zscore.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0     -0.907825     1.053430     -1.336763    -1.312509  Iris-setosa
# 1     -1.152507    -0.110540     -1.336763    -1.312509  Iris-setosa
# 2     -1.009776     0.355048     -1.393408    -1.312509  Iris-setosa
# 3     -1.519530     0.122254     -1.280117    -1.312509  Iris-setosa
# 4     -1.030166     1.286224     -1.336763    -1.312509  Iris-setosa

# %%
data_normal.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      Species
# 0      0.222222     0.625000      0.067797     0.041667  Iris-setosa
# 1      0.166667     0.416667      0.067797     0.041667  Iris-setosa
# 2      0.199074     0.500000      0.050847     0.041667  Iris-setosa
# 3      0.083333     0.458333      0.084746     0.041667  Iris-setosa
# 4      0.194444     0.666667      0.067797     0.041667  Iris-setosa

# %% [markdown]
# NILAI RENTANG DATA

# %%
cetak_rentang(data_zscore) #pada hasil metode zscore
# Out:
# Rentang fitur sepal_length  adalah  4.4042740717592395
# Rentang fitur sepal_width  adalah  5.587057312242887
# Rentang fitur petal_length  adalah  3.342099429860446
# Rentang fitur petal_width  adalah  3.160938725348725

# %%
cetak_rentang(data_normal) #pada hasil metode minmax
# Out:
# Rentang fitur sepal_length  adalah  1.0
# Rentang fitur sepal_width  adalah  1.0
# Rentang fitur petal_length  adalah  1.0
# Rentang fitur petal_width  adalah  1.0

# %% [markdown]
# HASIL NILAI RATA-RATA

# %%
data_zscore.mean() #pada hasil metode zscore
# Out:
# <ipython-input-45-a44b5144057d>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_zscore.mean()
# sepal_length    4.736952e-16
# sepal_width    -1.894781e-16
# petal_length   -9.473903e-17
# petal_width    -2.842171e-16
# dtype: float64

# %%
data_normal.mean() #pada hasil metode minmax
# Out:
# <ipython-input-46-73866a534e12>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_normal.mean()
# sepal_length    0.428346
# sepal_width     0.436452
# petal_length    0.467774
# petal_width     0.456894
# dtype: float64

# %% [markdown]
# HASIL NILAI STARDAR DEVIASI

# %%
data_zscore.std()
# Out:
# <ipython-input-47-77ac2adc138e>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_zscore.std()
# sepal_length    1.0
# sepal_width     1.0
# petal_length    1.0
# petal_width     1.0
# dtype: float64

# %%
data_normal.std()
# Out:
# <ipython-input-48-40d6629a4db4>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_normal.std()
# sepal_length    0.227052
# sepal_width     0.178985
# petal_length    0.299213
# petal_width     0.316362
# dtype: float64

# %% [markdown]
# Metode normalisasi Min-Max dan Z-Score adalah dua pendekatan yang umum digunakan untuk mengubah skala data sehingga dapat diinterpretasikan atau digunakan secara lebih baik dalam analisis. Berikut adalah kesimpulan berdasarkan hasil normalisasi Min-Max dan Z-Score yang Anda berikan:
#
# 1. **Rentang Data:**
#    - Min-Max Normalization: Rentang fitur setiap variabel adalah 1.0. Metode ini mengubah nilai data ke dalam rentang tertentu, dalam hal ini, rentang dari 0 hingga 1.
#    - Z-Score Normalization: Rentang fitur bervariasi dan dinyatakan dalam satuan standar deviasi. Dalam contoh ini, rentang fitur sepal_length, sepal_width, petal_length, dan petal_width adalah sekitar 1.
#
# 2. **Nilai Rata-rata:**
#    - Min-Max Normalization: Nilai rata-rata setiap fitur variabel adalah sekitar 0,5. Metode ini menggeser dan mengubah skala data sehingga nilai rata-rata menjadi 0, dan nilai-nilai lainnya diubah sesuai dengan faktor skala.
#    - Z-Score Normalization: Nilai rata-rata setiap fitur variabel mendekati nol. Metode ini memusatkan data dengan mengurangkan nilai rata-rata sehingga distribusi data memiliki mean 0.
#
# 3. **Nilai Standar Deviasi:**
#    - Min-Max Normalization: Standar deviasi fitur variabel rendah, mendekati nol. Metode ini tidak memperhitungkan variabilitas asli data.
#    - Z-Score Normalization: Standar deviasi fitur variabel adalah sekitar 1. Metode ini mempertahankan variabilitas data asli dalam satuan standar deviasi.
#
# Kesimpulannya, Min-Max Normalization cocok untuk data yang memiliki rentang nilai yang jelas dan memiliki distribusi yang mendekati normal, sementara Z-Score Normalization lebih baik digunakan untuk data dengan distribusi yang tidak diketahui atau tidak mendekati normal, karena metode ini lebih tangguh terhadap pencilan (outliers). Pilihan antara keduanya tergantung pada karakteristik data yang Anda miliki.
